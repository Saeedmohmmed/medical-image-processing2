# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline
figure_size = 9
kernel = np.ones((5,5), np.uint8)
image = cv2.imread('xray.jpg') # reads the image
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) # convert to HSV
new_image = cv2.medianBlur(image, figure_size)
# erosion = cv2.erode(new_image, kernel, iterations = 1)
opening = cv2.morphologyEx(new_image, cv2.MORPH_OPEN, kernel)
blur = cv2.GaussianBlur(new_image, (5,5), 0)
_, th3 = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter with otsu threshold')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline
figure_size = 9
kernel = np.ones((5,5), np.uint8)
image = cv2.imread('xray.jpg') # reads the image
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) # convert to HSV
new_image = cv2.medianBlur(image, figure_size)
# erosion = cv2.erode(new_image, kernel, iterations = 1)
opening = cv2.morphologyEx(new_image, cv2.MORPH_OPEN, kernel)
thresh = cv2.adaptiveThreshold(new_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, 
                               cv2.THRESH_BINARY, 3, 5) 

plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter with adaptive thresh')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline
figure_size = 9
kernel = np.ones((5,5), np.uint8)
image = cv2.imread('xray.jpg') # reads the image
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) # convert to HSV
new_image = cv2.medianBlur(image, figure_size)
# erosion = cv2.erode(new_image, kernel, iterations = 1)
opening = cv2.morphologyEx(new_image, cv2.MORPH_OPEN, kernel)

ret,thresh5 = cv2.threshold(opening, 127, 255, cv2.THRESH_TOZERO_INV)


plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter thresh to zero inverse')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline
figure_size = 9
kernel = np.ones((5,5), np.uint8)
image = cv2.imread('xray.jpg') # reads the image
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) # convert to HSV
new_image = cv2.medianBlur(image, figure_size)
# erosion = cv2.erode(new_image, kernel, iterations = 1)
opening = cv2.morphologyEx(new_image, cv2.MORPH_OPEN, kernel)
ret,thresh4 = cv2.threshold(opening, 127, 255, cv2.THRESH_TOZERO)



plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter with thresh to zero')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline
figure_size = 9
kernel = np.ones((5,5), np.uint8)
image = cv2.imread('xray.jpg') # reads the image
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) # convert to HSV
new_image = cv2.medianBlur(image, figure_size)
# erosion = cv2.erode(new_image, kernel, iterations = 1)
opening = cv2.morphologyEx(new_image, cv2.MORPH_OPEN, kernel)
ret,thresh3 = cv2.threshold(opening, 127, 255, cv2.THRESH_TRUNC)
plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter with thresh trun')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline
figure_size = 9
kernel = np.ones((5,5), np.uint8)
image = cv2.imread('xray.jpg') # reads the image
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) # convert to HSV
new_image = cv2.medianBlur(image, figure_size)
# erosion = cv2.erode(new_image, kernel, iterations = 1)
opening = cv2.morphologyEx(new_image, cv2.MORPH_OPEN, kernel)
# ret,thresh1 = cv2.threshold(opening, 127, 255, cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(opening, 127, 255, cv2.THRESH_BINARY_INV)
plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter with thresh binary inv')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline
figure_size = 9
kernel = np.ones((5,5), np.uint8)
image = cv2.imread('xray.jpg') # reads the image
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) # convert to HSV
new_image = cv2.medianBlur(image, figure_size)
# erosion = cv2.erode(new_image, kernel, iterations = 1)
opening = cv2.morphologyEx(new_image, cv2.MORPH_OPEN, kernel)
ret,thresh1 = cv2.threshold(opening, 127, 255, cv2.THRESH_BINARY)

plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter with thresh binary')
plt.xticks([]), plt.yticks([])
plt.show()
